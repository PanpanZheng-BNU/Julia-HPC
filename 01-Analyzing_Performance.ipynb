# %% [markdown]
# ## C01 Analyzing Performance
# ### Timing Julia Functions
# - `@time` measure the time of expression run; **not return the time they used**
# - `@timev` enhanced `time`; **not return the time they used**
# - `@elapsed` **return the time of expression run**
#
# <mark style="background: #DB4D6D;">**Note**: for the first execute expression, the timing will record the time used for compile</mark>

# %%
@time sqrt.(rand(1000));
# Out:
#   0.000015 seconds (2 allocations: 15.875 KiB)

# %%
@time for i in 1:1000
    x = sin.(rand(1000))
end
# Out:
#   0.012573 seconds (2.00 k allocations: 15.503 MiB)

# %%
@timev sqrt.(rand(1000));
# Out:
#   0.000010 seconds (2 allocations: 15.875 KiB)
# elapsed time (ns)
# :  10387
# gc time (ns):       0
# bytes allocated:    16256
# pool allocs:        0
# non-pool GC allocs: 2
# minor collections:  0
# full collections:   0

# %%
a = @time sqrt.(rand(1000));
sum(@time sqrt.(rand(1000)));
println("\na = " * string(a))
# Out:
#   0.000012 seconds (2 allocations: 15.875 KiB)
#   0.000011 seconds (2 allocations: 15.875 KiB)
# a = [0.5721389865673566, 0.4095122784381285, 0.5951351884540552, 0.9782295221654991, 0.6391840220709095, 0.9185261635173686, 0.994341870743468, 0.6499100387462687, 0.9854435053656161, 0.7041976914343921, 0.598913882336577, 0.6376316321057297, 0.8985321783386664, 0.1374636866399775, 0.07216340196107471, 0.8967786223415228, 0.6955965155343523, 0.342760200719822, 0.8582729359308607, 0.7146077233505418, 0.5200815007786008, 0.4634134367296263, 0.4634136534617932, 0.8790062813431863, 0.8471862579005801, 0.6609554891266604, 0.8369505787828216, 0.6184007575730726, 0.637934843045257, 0.427228089681921, 0.5859848606488868, 0.5403380795759188, 0.8859602754503687, 0.8218710235273895, 0.6138274749935112, 0.913827905396697, 0.3842245694692903, 0.61021114454824, 0.7311960149034075, 0.8289801507996251, 0.9454889111347502, 0.8121082716838366, 0.7824050184297408, 0.8995718588250087, 0.5214260819049206, 0.8855292885336278, 0.5444276233026477, 0.4554823787157653, 0.9364935301913514, 0.2975104044928526, 0.9209436999883719, 0.9453822074323143, 0.4418329592641648, 0.7156479425032352, 0.7552881003727426, 0.9966740221922256, 0.5230735814607941, 0.09482430032672412, 0.9681094208001277, 0.6581646027415071, 0.8901997320942676, 0.8388973784453597, 0.9179975669419342, 0.5567063830165937, 0.9429100728082097, 0.8571252839180197, 0.9610812300286726, 0.23991648277528038, 0.3203115562970167, 0.8949363784354046, 0.5942619565631706, 0.3182313640085871, 0.5575965344554089, 0.694164663608375, 0.946161224475533, 0.9019011595997743, 0.7409131557436253, 0.19956243647328925, 0.8350349039285313, 0.3115395822693143, 0.5934674397282484, 0.5393956735390135, 0.5439684877699555, 0.978862452610125, 0.17365660119466522, 0.735927847630892, 0.5696356841274361, 0.6237579307628062, 0.292339995735563, 0.38611715908275607, 0.20420668367348457, 0.06547782006839745, 0.23060597565796734, 0.19818624181377711, 0.7792995970342553, 0.9163683839508959, 0.7662121580714877, 0.8750767805297976, 0.9688491274539636, 0.7462652327326905, 0.8032854079907134, 0.784582096385295, 0.9352784448373705, 0.460327522543955, 0.8046921739579872, 0.7319717423850355, 0.5925941701156403, 0.6065186784583332, 0.6533461861536974, 0.8182076971305544, 0.8295185198675171, 0.760758029619022, 0.5177754984372729, 0.8219034077275758, 0.8051233615836084, 0.5079445152813136, 0.5201723794507447, 0.22558538021592056, 0.947753173132786, 0.7415072358441337, 0.9453816306319887, 0.34639280853783994, 0.8946412485627381, 0.9668997572077743, 0.7638423071509591, 0.7510593155263082, 0.6326460231227458, 0.84472209972159, 0.9159874011066281, 0.6595659824923518, 0.7563024382962255, 0.999352158844731, 0.6525549350803692, 0.9865638284183931, 0.987757343547436, 0.44792277063054964, 0.8507744669992344, 0.7537338659519371, 0.5522942345389386, 0.7052524361422357, 0.9525179024938074, 0.8816965122675011, 0.8369280327709144, 0.4054852022761222, 0.7664199426131736, 0.6917059451916906, 0.8092313197355635, 0.9331612544098979, 0.9846137909905198, 0.461000630899676, 0.7991567089761265, 0.7265951523790084, 0.324836391733258, 0.5395002291725696, 0.821306782997684, 0.8352013770477894, 0.7212615046049804, 0.6123362503231075, 0.7824225796514286, 0.7487184572830987, 0.8476939852054102, 0.35973355537612917, 0.35452777505221184, 0.43445579249129407, 0.2848027265714259, 0.9724503616391075, 0.8434348162619902, 0.5716969827218128, 0.29285229480974123, 0.18875981807588757, 0.9764085505182436, 0.9487534235003526, 0.5417766381941707, 0.6954941238041106, 0.5449182088378285, 0.8493788383229001, 0.9490400580462636, 0.3046382089825083, 0.9690817438224234, 0.9072397493468536, 0.45431986407502234, 0.6690702221893641, 0.9236225985617729, 0.7082991358051332, 0.6863909704775646, 0.9717998745357757, 0.8247180203963005, 0.9193492275055704, 0.8551942578452123, 0.1481316438749467, 0.39992660832953575, 0.9326855744928347, 0.5992325918466435, 0.6966294428291753, 0.8100691973890467, 0.8671524747787852, 0.6977130260888947, 0.8482564839061312, 0.712231314344843, 0.43079808519248414, ...

# %%
a = @elapsed sqrt.(rand(1000))
println("a = " * string(a))
# Out:
# a = 9.261e-6

# %%
using Test
@test @elapsed(sqrt.(rand(1000))) <= 1e-3
# Out:
# Test Passed

# %% [markdown]
# ### The Julia Profiler
# > The profiler is used to identify bottlenecks in code
#
# - `Profile`
#   - `Profile.clear()`: clear the profile info stored in memory.
#   - `@profile`: record the profile of expression
#   - `Profile.print()`: show the profile info of expression.
#   - `Profile.init(delay=::Number)`: setting the *sampling interval*. defualt is `1ms` (`delay=.001`) in Linux. `.01` is `10ms`
# - The result of Profile
#   - The first field is the count time, which is determined by the interval of count. The larger number of count times represents this part take longer time to run.
#   - For long-running program, we need to set larger interval.
# - `TimerOutputs`: **for long-runing program**
#   - `const to = TimerOutput();`: define a global `TimerOutput`, and pass it to `to`
#   - `@time to::TimerOutput "name"::String`
#   - `print_timer(to::TimerOutput)`

# %%
using Profile

# %%
using Statistics
function randmsq()
    x = rand(10000,1000)
    y = mean(x .^2, dims=1)
    return y
end
# Out:
# randmsq (generic function with 1 method)

# %%
randmsq();
Profile.clear()
Profile.init(delay = .001)
@profile randmsq();
Profile.print()
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#    ╎16  @Base/Base.jl:608; (::Base.var"#1055#1056")()
#    ╎ 16  @Base/Base.jl:572; profile_printing_listener()
#    ╎  16  @Base/asyncevent.jl:159; wait
#    ╎   16  @Base/asyncevent.jl:142; _trywait(t::Base.AsyncCondition)
#    ╎    16  @Base/condition.jl:125; wait
#    ╎     16  @Base/condition.jl:130; wait(c::Base.GenericCondition...
#    ╎    ╎ 16  @Base/task.jl:994; wait()
#  16╎    ╎  16  @Base/task.jl:985; poptask(W::Base.IntrusiveLin...
#    ╎16  @Base/client.jl:552; _start()
#    ╎ 16  @Base/client.jl:318; exec_options(opts::Base.JLOptions)
#    ╎  16  @Base/Base.jl:495; include(mod::Module, _path::Str...
#    ╎   16  @Base/loading.jl:2130; _include(mapexpr::Function, mo...
#    ╎    16  @Base/loading.jl:2070; include_string(mapexpr::typeo...
#    ╎     16  @Base/boot.jl:385; eval
#    ╎    ╎ 16  ...tebook/notebook.jl:32; top-level scope
#    ╎    ╎  16  .../serve_notebook.jl:75; kwcall(::@NamedTuple{crashre...
#    ╎    ╎   16  ...serve_notebook.jl:139; serve_notebook(pipename::St...
#    ╎    ╎    16  ...NRPC/src/typed.jl:67; dispatch_msg(x::VSCodeServe...
#    ╎    ╎     16  ...serve_notebook.jl:13; notebook_runcell_request(co...
#    ╎    ╎    ╎ 16  ...rver/src/repl.jl:274; withpath(f::VSCodeServer....
#    ╎    ╎    ╎  16  ...erve_notebook.jl:19; (::VSCodeServer.var"#208#...
#    ╎    ╎    ╎   16  ...e/essentials.jl:884; invokelatest
#    ╎    ╎    ╎    16  ...e/essentials.jl:887; #invokelatest#2
#    ╎    ╎    ╎     16  @Base/loading.jl:2070; include_string(mapexpr...
#   1╎    ╎    ╎    ╎ 16  @Base/boot.jl:385; eval
#    ╎    ╎    ╎    ╎  5   ...formance.ipynb:3; randmsq()
#    ╎    ╎    ╎    ╎   5   ...src/Random.jl:279; rand
#    ╎    ╎    ╎    ╎    5   ...src/Random.jl:291; rand
#    ╎    ╎    ╎    ╎     5   ...rc/Random.jl:290; rand
#    ╎    ╎    ╎    ╎    ╎ 2   @Base/boot.jl:494; Array
#    ╎    ╎    ╎    ╎    ╎  2   @Base/boot.jl:487; Array
#   2╎    ╎    ╎    ╎    ╎   2   @Base/boot.jl:479; Array
#    ╎    ╎    ╎    ╎    ╎ 3   ...rc/Random.jl:269; rand!
#    ╎    ╎    ╎    ╎    ╎  3   ...hiroSimd.jl:293; rand!
#    ╎    ╎    ╎    ╎    ╎   3   ...hiroSimd.jl:142; xoshiro_bulk
#    ╎    ╎    ╎    ╎    ╎    3   ...hiroSimd.jl:257; xoshiro_bulk_simd
#    ╎    ╎    ╎    ╎    ╎     2   ...pointer.jl:146; unsafe_store!
#   2╎    ╎    ╎    ╎    ╎    ╎ 2   ...pointer.jl:146; unsafe_store!
#   1╎    ╎    ╎    ╎    ╎     1   ...iroSimd.jl:108; _bits2float
#    ╎    ╎    ╎    ╎  10  ...formance.ipynb:4; randmsq()
#    ╎    ╎    ╎    ╎   8   .../broadcast.jl:903; materialize
#    ╎    ╎    ╎    ╎    8   .../broadcast.jl:928; copy
#    ╎    ╎    ╎    ╎     3   ...broadcast.jl:956; copyto!
#    ╎    ╎    ╎    ╎    ╎ 3   ...roadcast.jl:1003; copyto!
#    ╎    ╎    ╎    ╎    ╎  3   .../simdloop.jl:77; macro expansion
#    ╎    ╎    ╎    ╎    ╎   3   ...roadcast.jl:1004; macro expansion
#    ╎    ╎    ╎    ╎    ╎    2   ...roadcast.jl:636; getindex
#    ╎    ╎    ╎    ╎    ╎     1   ...oadcast.jl:681; _broadcast_getindex
#    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...oadcast.jl:705; _getindex
#    ╎    ╎    ╎    ╎    ╎    ╎  1   ...adcast.jl:705; _getindex
#    ╎    ╎    ╎    ╎    ╎    ╎   1   ...adcast.jl:675; _broadcast_geti...
#    ╎    ╎    ╎    ╎    ╎    ╎    1   ...sional.jl:696; getindex
#   1╎    ╎    ╎    ╎    ╎    ╎     1   ...ntials.jl:14; getindex
#    ╎    ╎    ╎    ╎    ╎     1   ...oadcast.jl:682; _broadcast_getindex
#    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...oadcast.jl:709; _broadcast_getin...
#    ╎    ╎    ╎    ╎    ╎    ╎  1   ...tfuncs.jl:332; literal_pow
#   1╎    ╎    ╎    ╎    ╎    ╎   1   .../float.jl:411; *
#    ╎    ╎    ╎    ╎    ╎    1   ...ensional.jl:698; setindex!
#   1╎    ╎    ╎    ╎    ╎     1   ...e/array.jl:1024; setindex!
#    ╎    ╎    ╎    ╎     5   ...broadcast.jl:223; similar
#    ╎    ╎    ╎    ╎    ╎ 5   ...broadcast.jl:224; similar
#    ╎    ╎    ╎    ╎    ╎  5   ...actarray.jl:873; similar
#    ╎    ╎    ╎    ╎    ╎   5   ...actarray.jl:874; similar
#    ╎    ╎    ╎    ╎    ╎    5   @Base/boot.jl:494; Array
#    ╎    ╎    ╎    ╎    ╎     5   @Base/boot.jl:487; Array
#   5╎    ╎    ╎    ╎    ╎    ╎ 5   @Base/boot.jl:479; Array
#    ╎    ╎    ╎    ╎   2   ...Statistics.jl:174; mean
#    ╎    ╎    ╎    ╎    2   ...Statistics.jl:174; #mean#2
#    ╎    ╎    ╎    ╎     2   ...tatistics.jl:187; _mean(f::typeof(iden...
#    ╎    ╎    ╎    ╎    ╎ 2   ...educedim.jl:1011; sum
#    ╎    ╎    ╎    ╎    ╎  2   ...educedim.jl:1011; #sum#829
#    ╎    ╎    ╎    ╎    ╎   2   ...educedim.jl:1039; _sum
#    ╎    ╎    ╎    ╎    ╎    2   ...ducedim.jl:1039; #_sum#855
#    ╎    ╎    ╎    ╎    ╎     2   ...ducedim.jl:357; mapreduce
#    ╎    ╎    ╎    ╎    ╎    ╎ 2   ...ducedim.jl:357; #mapreduce#821
#    ╎    ╎    ╎    ╎    ╎    ╎  2   ...ucedim.jl:371; _mapreduce_dim
#    ╎    ╎    ╎    ╎    ╎    ╎   2   ...ucedim.jl:324; mapreducedim!
#    ╎    ╎    ╎    ╎    ╎    ╎    2   ...ucedim.jl:295; _mapreducedim!(...
#    ╎    ╎    ╎    ╎    ╎    ╎     2   ...reduce.jl:277; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 2   ...reduce.jl:272; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎  2   ...reduce.jl:272; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎   2   ...reduce.jl:271; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎    2   ...reduce.jl:272; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎     2   ...reduce.jl:263; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 2   ...mdloop.jl:77; macro expansion
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  2   ...reduce.jl:265; macro expansion
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   2   ...reduce.jl:27; add_sum
#   2╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    2   .../float.jl:409; +
#    ╎288 @Base/task.jl:675; task_done_hook(t::Task)
#    ╎ 288 @Base/task.jl:994; wait()
# 287╎  288 @Base/task.jl:985; poptask(W::Base.IntrusiveLinked...
# Total snapshots: 320. Utilization: 5% across all threads and tasks. Use the `groupby` kwarg to break down by thread and/or task.

# %%
using TimerOutputs
const to = TimerOutput();

function randmsq_timed()
    @timeit to "randmsq" begin
        x = @timeit to "rand" rand(10000,1000)
        y = @timeit to "mean" mean(x .^2, dims=1)
    end
end
# Out:
# randmsq_timed (generic function with 1 method)

# %%
randmsq_timed();
print_timer(to)
# Out:
#  ────────────────────────────────────────────────────────────────────
#                             Time                    Allocations
#                    ───────────────────────   ────────────────────────
#  Tot / % measured:      330ms /  14.6%            174MiB /  87.8%
#
#  Section   ncalls     time    %tot     avg     alloc    %tot      avg
#  ────────────────────────────────────────────────────────────────────
#  randmsq        1   48.3ms  100.0%  48.3ms    153MiB  100.0%   153MiB
#    rand         1   26.4ms   54.7%  26.4ms   76.3MiB   50.0%  76.3MiB
#    mean         1   21.8ms   45.2%  21.8ms   76.3MiB   50.0%  76.3MiB
#  ────────────────────────────────────────────────────────────────────

# %%
const to_myself = TimerOutput();
function testmy()
    @timeit to_myself "forloop" for i in 1:1000
            x = sin.(rand(1000))
    end
    @timeit to_myself "parallel_for" begin
        Threads.@threads for i in 1:1000
            x = sin.(rand(1000))
        end
    end
end
# Out:
# testmy (generic function with 1 method)

# %%
testmy();
print_timer(to_myself)
# Out:
#  ─────────────────────────────────────────────────────────────────────────
#                                  Time                    Allocations
#                         ───────────────────────   ────────────────────────
#     Tot / % measured:        230ms /  41.0%           36.0MiB /  89.2%
#
#  Section        ncalls     time    %tot     avg     alloc    %tot      avg
#  ─────────────────────────────────────────────────────────────────────────
#  parallel_for        1   84.4ms   89.5%  84.4ms   16.6MiB   51.6%  16.6MiB
#  forloop             1   9.87ms   10.5%  9.87ms   15.5MiB   48.4%  15.5MiB
#  ─────────────────────────────────────────────────────────────────────────
