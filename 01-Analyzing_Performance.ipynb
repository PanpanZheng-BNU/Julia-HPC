# %% [markdown]
# ## C01 Analyzing Performance
# ### Timing Julia Functions
# - `@time` measure the time of expression run; **not return the time they used**
# - `@timev` enhanced `time`; **not return the time they used**
# - `@elapsed` **return the time of expression run**
#
# <mark style="background: #DB4D6D;">**Note**: for the first execute expression, the timing will record the time used for compile</mark>

# %%
@time sqrt.(rand(1000));
# Out:
#   0.000006 seconds (2 allocations: 15.875 KiB)

# %%
@time for i in 1:1000
    x = sin.(rand(1000))
end
# Out:
#   0.011463 seconds (2.00 k allocations: 15.503 MiB)

# %%
@timev sqrt.(rand(1000));
# Out:
#   0.000005 seconds (2 allocations: 15.875 KiB)
# elapsed time (ns):  5208
# gc time (ns):       0
# bytes allocated:    16256
# pool allocs:        0
# non-pool GC allocs: 2
# minor collections:  0
# full collections:   0

# %%
a = @time sqrt.(rand(1000));
sum(@time sqrt.(rand(1000)));
println("\na = " * string(a))
# Out:
#   0.000006 seconds (2 allocations: 15.875 KiB)
#   0.000005 seconds (2 allocations: 15.875 KiB)
#
# a = [0.22928406642301435, 0.6355696173000532, 0.7507026474740647, 0.4083889107037258, 0.9078622457560449, 0.5986201416729272, 0.9913453779874813, 0.6909087295791443, 0.3349598781092458, 0.4059871584897557, 0.6376673215695967, 0.30864910243070925, 0.3555903895197032, 0.7562427086712816, 0.7020433480815743, 0.795625096415106, 0.8387906036459296, 0.7811308943494811, 0.9485721002343293, 0.7418204693059206, 0.48528316491694107, 0.8483360526747398, 0.9391562499724064, 0.4798687951642979, 0.5220655287300909, 0.9714791628953767, 0.9914092730328488, 0.8313618969477511, 0.9171728318656901, 0.3725181688459916, 0.46252928615414174, 0.7489396869964122, 0.3429257794939777, 0.7846844866797308, 0.9237726611775696, 0.7550797088174407, 0.6043206201765189, 0.9542891586066216, 0.7718259458135409, 0.6563237998547797, 0.8587371502427545, 0.7852884300094256, 0.7531773991891628, 0.7215169131540982, 0.8515417937270495, 0.40638237528283516, 0.9665833361619806, 0.966592452924239, 0.3032232363253759, 0.8519535527111022, 0.9634854161881963, 0.8448215382114306, 0.8638233098026493, 0.41564976750980037, 0.7616454603310808, 0.8952568967251501, 0.285314528138705, 0.17179508643313204, 0.2573408472137253, 0.39338154908787126, 0.7978408910481863, 0.961036577136888, 0.6715723023474643, 0.8911610152721819, 0.755910429672437, 0.2957936609399514, 0.7300397185000265, 0.935070705931327, 0.2174046026224235, 0.8322868175984672, 0.15478504790717823, 0.5253689330231698, 0.9439778074946082, 0.7411151295211299, 0.8164473673321827, 0.7166613117474392, 0.9325201626697079, 0.8248490256965961, 0.9267625643475835, 0.66632950566115, 0.8091558340074726, 0.4612806803027708, 0.6672455351974464, 0.9199782158044808, 0.4325307867062187, 0.39274602863550206, 0.5582181689233628, 0.5614922722727956, 0.9861270099464827, 0.8529967428082328, 0.5970944216151685, 0.6659005350979839, 0.8532118345872419, 0.4981571353365502, 0.5184556657540085, 0.7966059805650338, 0.8489757505153744, 0.4270566685394735, 0.49981260227106383, 0.41385850409702785, 0.8742009569867143, 0.6051464627101154, 0.9839850796393136, 0.7594365335704265, 0.8810421325923516, 0.9310790671174605, 0.8652912668629049, 0.6310197658836854, 0.2409544300885609, 0.7019116818327416, 0.33283733179620556, 0.8715175878564628, 0.43227334346079305, 0.9462436356722664, 0.5779531275851577, 0.33968438323181666, 0.2935510897225997, 0.5036447492456153, 0.48155699538565566, 0.4760416725036398, 0.9640400723017417, 0.7266903688647797, 0.8031214143981669, 0.3145342479985996, 0.9976531486750319, 0.7960551362576194, 0.26618554973807274, 0.7675556026671474, 0.9505665029644191, 0.8667677229517616, 0.09555425266409853, 0.9268526616609817, 0.7125216708859398, 0.4275401014757673, 0.3226039110762367, 0.5228434485775886, 0.8268829622296182, 0.8035584427844601, 0.9869663725525648, 0.6692652081962872, 0.2887345018453031, 0.7291256473311107, 0.23927776690151367, 0.27985829627338404, 0.8211318867723876, 0.4506173530792405, 0.8336128882968544, 0.8222432137699649, 0.654518678715004, 0.49610398663998745, 0.9133493051655792, 0.8086365216003647, 0.8476903888662138, 0.8653857488796372, 0.48969941088828217, 0.7102666549159949, 0.3049893171932341, 0.9817355169000865, 0.8548674375691423, 0.8378156827263169, 0.4477121538693379, 0.6886772939016125, 0.3272251805597317, 0.43084387578877786, 0.8737142222915626, 0.729567783145635, 0.8394197353879765, 0.7623045563866686, 0.5130853113424395, 0.8836915936916843, 0.5983857714178261, 0.4330073244485937, 0.5134673519659545, 0.8498790810003362, 0.854966480987174, 0.949287941114325, 0.842013387961968, 0.08638940429222511, 0.6739108314671568, 0.276312969408119, 0.366378739556777, 0.6977527997163164, 0.7351575698566315, 0.8536252135526563, 0.4374104747693409, 0.43812733387466063, 0.4197076870454837, 0.6731045759486386, 0.7777092886021717, 0.7954533788837908, 0.9479209815527838, 0.615601499746167, 0.7587237607942027, 0.8939823487264893, 0.9498134433461101, 0.6913969264739034, 0.8202791238931972, 0.3287262218437092, 0.9756908187021728, 0.7831 ...

# %%
a = @elapsed sqrt.(rand(1000))
println("a = " * string(a))
# Out:
# a = 6.083e-6

# %%
using Test
@test @elapsed(sqrt.(rand(1000))) <= 1e-5
# Out:
# Test Passed

# %% [markdown]
# ### The Julia Profiler
# > The profiler is used to identify bottlenecks in code
#
# - `Profile`
#   - `Profile.clear()`: clear the profile info stored in memory.
#   - `@profile`: record the profile of expression
#   - `Profile.print()`: show the profile info of expression.
#   - `Profile.init(delay=::Number)`: setting the *sampling interval*. defualt is `1ms` (`delay=.001`) in Linux. `.01` is `10ms`
# - The result of Profile
#   - The first field is the count time, which is determined by the interval of count. The larger number of count times represents this part take longer time to run.
#   - For long-running program, we need to set larger interval.
# - `TimerOutputs`: **for long-runing program**
#   - `const to = TimerOutput();`: define a global `TimerOutput`, and pass it to `to`
#   - `@time to::TimerOutput "name"::String`
#   - `print_timer(to::TimerOutput)`

# %%
using Profile

# %%
using Statistics
function randmsq()
    x = rand(10000,1000)
    y = mean(x .^2, dims=1)
    return y
end
# Out:
# randmsq (generic function with 1 method)

# %%
randmsq();
Profile.clear()
Profile.init(delay = .001)
@profile randmsq();
Profile.print()
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#    ╎16  @Base/client.jl:552; _start()
#    ╎ 16  @Base/client.jl:318; exec_options(opts::Base.JLOptions)
#    ╎  16  @Base/Base.jl:495; include(mod::Module, _path::Str...
#    ╎   16  @Base/loading.jl:2130; _include(mapexpr::Function, mo...
#    ╎    16  @Base/loading.jl:2070; include_string(mapexpr::typeo...
#    ╎     16  @Base/boot.jl:385; eval
#    ╎    ╎ 16  ...tebook/notebook.jl:32; top-level scope
#    ╎    ╎  16  .../serve_notebook.jl:75; kwcall(::@NamedTuple{crashre...
#    ╎    ╎   16  ...serve_notebook.jl:139; serve_notebook(pipename::St...
#    ╎    ╎    16  ...NRPC/src/typed.jl:67; dispatch_msg(x::VSCodeServe...
#    ╎    ╎     16  ...serve_notebook.jl:13; notebook_runcell_request(co...
#    ╎    ╎    ╎ 16  ...rver/src/repl.jl:274; withpath(f::VSCodeServer....
#    ╎    ╎    ╎  16  ...erve_notebook.jl:19; (::VSCodeServer.var"#208#...
#    ╎    ╎    ╎   16  ...e/essentials.jl:884; invokelatest
#    ╎    ╎    ╎    16  ...e/essentials.jl:887; #invokelatest#2
#    ╎    ╎    ╎     16  @Base/loading.jl:2070; include_string(mapexpr...
#    ╎    ╎    ╎    ╎ 16  @Base/boot.jl:385; eval
#    ╎    ╎    ╎    ╎  9   ...formance.ipynb:3; randmsq()
#    ╎    ╎    ╎    ╎   9   ...src/Random.jl:279; rand
#    ╎    ╎    ╎    ╎    9   ...src/Random.jl:291; rand
#    ╎    ╎    ╎    ╎     9   ...rc/Random.jl:290; rand
#    ╎    ╎    ╎    ╎    ╎ 9   ...rc/Random.jl:269; rand!
#    ╎    ╎    ╎    ╎    ╎  9   ...hiroSimd.jl:293; rand!
#    ╎    ╎    ╎    ╎    ╎   9   ...hiroSimd.jl:142; xoshiro_bulk
#   1╎    ╎    ╎    ╎    ╎    1   ...hiroSimd.jl:248; xoshiro_bulk_simd(...
#    ╎    ╎    ╎    ╎    ╎    1   ...hiroSimd.jl:253; xoshiro_bulk_simd(...
#   1╎    ╎    ╎    ╎    ╎     1   ...hiroSimd.jl:77; _xor
#    ╎    ╎    ╎    ╎    ╎    2   ...hiroSimd.jl:255; xoshiro_bulk_simd(...
#   2╎    ╎    ╎    ╎    ╎     2   ...hiroSimd.jl:77; _xor
#    ╎    ╎    ╎    ╎    ╎    2   ...hiroSimd.jl:256; xoshiro_bulk_simd(...
#   2╎    ╎    ╎    ╎    ╎     2   ...hiroSimd.jl:55; _rotl45
#    ╎    ╎    ╎    ╎    ╎    3   ...hiroSimd.jl:257; xoshiro_bulk_simd(...
#    ╎    ╎    ╎    ╎    ╎     2   ...pointer.jl:146; unsafe_store!
#   2╎    ╎    ╎    ╎    ╎    ╎ 2   ...pointer.jl:146; unsafe_store!
#   1╎    ╎    ╎    ╎    ╎     1   ...iroSimd.jl:108; _bits2float
#    ╎    ╎    ╎    ╎  7   ...formance.ipynb:4; randmsq()
#    ╎    ╎    ╎    ╎   6   .../broadcast.jl:903; materialize
#    ╎    ╎    ╎    ╎    6   .../broadcast.jl:928; copy
#    ╎    ╎    ╎    ╎     6   ...broadcast.jl:956; copyto!
#    ╎    ╎    ╎    ╎    ╎ 6   ...roadcast.jl:1003; copyto!
#    ╎    ╎    ╎    ╎    ╎  6   .../simdloop.jl:77; macro expansion
#    ╎    ╎    ╎    ╎    ╎   6   ...roadcast.jl:1004; macro expansion
#    ╎    ╎    ╎    ╎    ╎    2   ...roadcast.jl:636; getindex
#    ╎    ╎    ╎    ╎    ╎     2   ...oadcast.jl:681; _broadcast_getindex
#    ╎    ╎    ╎    ╎    ╎    ╎ 2   ...oadcast.jl:705; _getindex
#    ╎    ╎    ╎    ╎    ╎    ╎  2   ...adcast.jl:705; _getindex
#    ╎    ╎    ╎    ╎    ╎    ╎   2   ...adcast.jl:675; _broadcast_geti...
#    ╎    ╎    ╎    ╎    ╎    ╎    2   ...sional.jl:696; getindex
#   2╎    ╎    ╎    ╎    ╎    ╎     2   ...ntials.jl:14; getindex
#    ╎    ╎    ╎    ╎    ╎    4   ...ensional.jl:698; setindex!
#   4╎    ╎    ╎    ╎    ╎     4   ...e/array.jl:1024; setindex!
#    ╎    ╎    ╎    ╎   1   ...Statistics.jl:174; mean
#    ╎    ╎    ╎    ╎    1   ...Statistics.jl:174; #mean#2
#    ╎    ╎    ╎    ╎     1   ...tatistics.jl:187; _mean(f::typeof(iden...
#    ╎    ╎    ╎    ╎    ╎ 1   ...educedim.jl:1011; sum
#    ╎    ╎    ╎    ╎    ╎  1   ...educedim.jl:1011; #sum#829
#    ╎    ╎    ╎    ╎    ╎   1   ...educedim.jl:1039; _sum
#    ╎    ╎    ╎    ╎    ╎    1   ...ducedim.jl:1039; #_sum#855
#    ╎    ╎    ╎    ╎    ╎     1   ...ducedim.jl:357; mapreduce
#    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...ducedim.jl:357; #mapreduce#821
#    ╎    ╎    ╎    ╎    ╎    ╎  1   ...ucedim.jl:371; _mapreduce_dim
#    ╎    ╎    ╎    ╎    ╎    ╎   1   ...ucedim.jl:324; mapreducedim!
#    ╎    ╎    ╎    ╎    ╎    ╎    1   ...ucedim.jl:295; _mapreducedim!(...
#    ╎    ╎    ╎    ╎    ╎    ╎     1   ...reduce.jl:277; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...reduce.jl:271; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1   ...reduce.jl:271; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1   ...reduce.jl:272; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1   ...reduce.jl:272; mapreduce_impl(...
#    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1   ...reduce.jl:263; mapreduce_impl(...
#   1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1   ...mdloop.jl:75; macro expansion
# Total snapshots: 136. Utilization: 12% across all threads and tasks. Use the `groupby` kwarg to break down by thread and/or task.

# %%
using TimerOutputs
const to = TimerOutput();

function randmsq_timed()
    @timeit to "randmsq" begin
        x = @timeit to "rand" rand(10000,1000)
        y = @timeit to "mean" mean(x .^2, dims=1)
    end
end
# Out:
# randmsq_timed (generic function with 1 method)

# %%
randmsq_timed();
print_timer(to)
# Out:
#  ────────────────────────────────────────────────────────────────────
#                             Time                    Allocations
#                    ───────────────────────   ────────────────────────
#  Tot / % measured:      1302s /   0.0%           3.69GiB /  48.4%
#
#  Section   ncalls     time    %tot     avg     alloc    %tot      avg
#  ────────────────────────────────────────────────────────────────────
#  randmsq       12    395ms  100.0%  33.0ms   1.79GiB  100.0%   153MiB
#    rand        12    251ms   63.4%  20.9ms    916MiB   50.0%  76.3MiB
#    mean        12    145ms   36.6%  12.1ms    916MiB   50.0%  76.3MiB
#  ────────────────────────────────────────────────────────────────────

# %%
const to_myself = TimerOutput();
function testmy()
    @timeit to_myself "forloop" for i in 1:1000
            x = sin.(rand(1000))
    end
    @timeit to_myself "parallel_for" begin
        Threads.@threads for i in 1:1000
            x = sin.(rand(1000))
        end
    end
end
# Out:
# WARNING: redefinition of constant Main.to_myself. This may fail, cause incorrect answers, or produce other errors.
# testmy (generic function with 1 method)

# %%
testmy();
print_timer(to_myself)
# Out:
#  ─────────────────────────────────────────────────────────────────────────
#                                  Time                    Allocations
#                         ───────────────────────   ────────────────────────
#     Tot / % measured:        835ms /   4.5%           35.0MiB /  91.6%
#
#  Section        ncalls     time    %tot     avg     alloc    %tot      avg
#  ─────────────────────────────────────────────────────────────────────────
#  parallel_for        1   23.6ms   62.6%  23.6ms   16.5MiB   51.6%  16.5MiB
#  forloop             1   14.1ms   37.4%  14.1ms   15.5MiB   48.4%  15.5MiB
#  ─────────────────────────────────────────────────────────────────────────
